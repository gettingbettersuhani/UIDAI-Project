# %% [markdown]
# <a href="https://colab.research.google.com/github/gettingbettersuhani/UIDAI-Project/blob/main/Biometric.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EDA on Biometric Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Importing libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Importing Demography-1 file

# %%
demo_1=pd.read_csv("/content/drive/MyDrive/api_data_aadhar_biometric/api_data_aadhar_biometric_0_500000.csv")
demo_1.head()
# Out:
#          date              state      district  pincode  bio_age_5_17  \
# 0  01-03-2025            Haryana  Mahendragarh   123029           280
# 1  01-03-2025              Bihar     Madhepura   852121           144
# 2  01-03-2025  Jammu and Kashmir         Punch   185101           643
# 3  01-03-2025              Bihar       Bhojpur   802158           256
# 4  01-03-2025         Tamil Nadu       Madurai   625514           271
#
#    bio_age_17_
# 0          577
# 1          369
# 2         1091
# 3          980
# 4          815

# %%
demo_1.shape
# Out:
# (500000, 6)

# %%
demo_1['state'].unique()
# Out:
# array(['Haryana', 'Bihar', 'Jammu and Kashmir', 'Tamil Nadu',
#        'Maharashtra', 'Gujarat', 'Odisha', 'West Bengal', 'Kerala',
#        'Rajasthan', 'Punjab', 'Himachal Pradesh', 'Uttar Pradesh',
#        'Assam', 'Uttarakhand', 'Madhya Pradesh', 'Karnataka',
#        'Andhra Pradesh', 'Telangana', 'Goa', 'Nagaland', 'Jharkhand',
#        'Delhi', 'Chhattisgarh', 'Meghalaya', 'Chandigarh', 'Orissa',
#        'Puducherry', 'Pondicherry', 'Manipur', 'Sikkim', 'Tripura',
#        'Mizoram', 'Arunachal Pradesh', 'Ladakh',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Daman and Diu',
#        'Andaman and Nicobar Islands', 'Andaman & Nicobar Islands',
#        'Dadra and Nagar Haveli', 'Lakshadweep', 'Daman & Diu',
#        'Dadra & Nagar Haveli', 'Jammu & Kashmir', 'WESTBENGAL',
#        'andhra pradesh', 'Westbengal', 'West  Bengal', 'WEST BENGAL',
#        'West Bangal', 'ODISHA', 'odisha', 'West bengal', 'west Bengal',
#        'Uttaranchal', 'Chhatisgarh'], dtype=object)

# %%
demo_1['new_date']=pd.to_datetime(demo_1['date'], format='%d-%m-%Y').dt.strftime('%Y%m%d')
demo_1
# Out:
#               date              state      district  pincode  bio_age_5_17  \
# 0       01-03-2025            Haryana  Mahendragarh   123029           280
# 1       01-03-2025              Bihar     Madhepura   852121           144
# 2       01-03-2025  Jammu and Kashmir         Punch   185101           643
# 3       01-03-2025              Bihar       Bhojpur   802158           256
# 4       01-03-2025         Tamil Nadu       Madurai   625514           271
# ...            ...                ...           ...      ...           ...
# 499995  19-09-2025              Delhi    West Delhi   110041           102
# 499996  19-09-2025              Delhi    West Delhi   110043             8
# 499997  19-09-2025              Delhi    West Delhi   110058             7
# 499998  19-09-2025                Goa     North Goa   403102             1
# 499999  19-09-2025                Goa     North Goa   403106             1
#
#         bio_age_17_  new_date
# 0               577  20250301
# 1               369  20250301
# 2              1091  20250301
# 3               980  20250301
# 4               815  20250301
# ...             ...       ...
# 499995          100  20250919
# 499996            5  20250919
# 499997            5  20250919
# 499998            0  20250919
# 499999            0  20250919
#
# [500000 rows x 7 columns]

# %%
demo_1['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
print(demo_1['new_date'].max())
print(demo_1['new_date'].min())
# Out:
# 20250919
# 20250301

# %%
demo_2.dtypes
# Out:
# date            object
# state           object
# district        object
# pincode          int64
# bio_age_5_17     int64
# bio_age_17_      int64
# new_date        object
# dtype: object

# %% [markdown]
# ### Importing Demography-2 File

# %%
demo_2=pd.read_csv("/content/drive/MyDrive/api_data_aadhar_biometric/api_data_aadhar_biometric_1000000_1500000.csv")
demo_2.head()
# Out:
#          date             state      district  pincode  bio_age_5_17  \
# 0  07-11-2025           Haryana  Yamuna Nagar   135002             4
# 1  07-11-2025           Haryana   Yamunanagar   135001             1
# 2  07-11-2025  Himachal Pradesh      Bilaspur   174004             2
# 3  07-11-2025  Himachal Pradesh      Bilaspur   174005             1
# 4  07-11-2025  Himachal Pradesh      Bilaspur   174013             3
#
#    bio_age_17_
# 0            6
# 1            2
# 2            2
# 3            0
# 4            1

# %%
demo_2.shape
# Out:
# (500000, 6)

# %%
demo_2['state'].unique()
# Out:
# array(['Haryana', 'Himachal Pradesh', 'Jammu and Kashmir', 'Jharkhand',
#        'Karnataka', 'Kerala', 'Lakshadweep', 'Madhya Pradesh',
#        'Maharashtra', 'Andaman & Nicobar Islands',
#        'Andaman and Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal', 'Chandigarh', 'Chhattisgarh',
#        'Dadra & Nagar Haveli', 'Dadra and Nagar Haveli', 'Daman & Diu',
#        'Daman and Diu', 'Delhi', 'Goa', 'Gujarat', 'Jammu & Kashmir',
#        'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Orissa',
#        'Pondicherry', 'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim',
#        'Tamil Nadu', 'Telangana', 'Tripura', 'Ladakh', 'West Bangal',
#        'West bengal', 'odisha',
#        'Dadra and Nagar Haveli and Daman and Diu', 'West  Bengal',
#        'WEST BENGAL', 'andhra pradesh', 'Westbengal', 'Chhatisgarh',
#        'ODISHA', 'WESTBENGAL', 'Uttaranchal'], dtype=object)

# %%
demo_2['new_date']=pd.to_datetime(demo_2['date'], format='%d-%m-%Y').dt.strftime('%Y%m%d')
demo_2
# Out:
#               date             state      district  pincode  bio_age_5_17  \
# 0       07-11-2025           Haryana  Yamuna Nagar   135002             4
# 1       07-11-2025           Haryana   Yamunanagar   135001             1
# 2       07-11-2025  Himachal Pradesh      Bilaspur   174004             2
# 3       07-11-2025  Himachal Pradesh      Bilaspur   174005             1
# 4       07-11-2025  Himachal Pradesh      Bilaspur   174013             3
# ...            ...               ...           ...      ...           ...
# 499995  08-12-2025           Gujarat      Vadodara   391150             3
# 499996  08-12-2025           Gujarat      Vadodara   391168            11
# 499997  08-12-2025           Gujarat      Vadodara   391170             0
# 499998  08-12-2025           Gujarat      Vadodara   391410             9
# 499999  08-12-2025           Gujarat      Vadodara   391530             3
#
#         bio_age_17_  new_date
# 0                 6  20251107
# 1                 2  20251107
# 2                 2  20251107
# 3                 0  20251107
# 4                 1  20251107
# ...             ...       ...
# 499995           18  20251208
# 499996           34  20251208
# 499997           23  20251208
# 499998            4  20251208
# 499999            7  20251208
#
# [500000 rows x 7 columns]

# %%
demo_2['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
print(demo_2['new_date'].max())
print(demo_2['new_date'].min())
# Out:
# 20251208
# 20251107

# %%
demo_2.dtypes
# Out:
# date            object
# state           object
# district        object
# pincode          int64
# bio_age_5_17     int64
# bio_age_17_      int64
# new_date        object
# dtype: object

# %% [markdown]
# ### Importing Demography-3 file

# %%
demo_3=pd.read_csv("/content/drive/MyDrive/api_data_aadhar_biometric/api_data_aadhar_biometric_1500000_1861108.csv")
demo_3.head()
# Out:
#          date          state       district  pincode  bio_age_5_17  \
# 0  08-12-2025  Uttar Pradesh      Moradabad   244411             4
# 1  08-12-2025  Uttar Pradesh      Moradabad   244601            14
# 2  08-12-2025  Uttar Pradesh  Muzaffarnagar   251002            22
# 3  08-12-2025  Uttar Pradesh  Muzaffarnagar   251202             4
# 4  08-12-2025  Uttar Pradesh  Muzaffarnagar   251319             4
#
#    bio_age_17_
# 0            2
# 1           19
# 2           37
# 3            4
# 4            7

# %%
demo_3.shape
# Out:
# (361108, 6)

# %%
demo_3['state'].unique()
# Out:
# array(['Uttar Pradesh', 'Uttarakhand', 'West Bangal', 'West Bengal',
#        'West bengal', 'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu and Kashmir',
#        'Jharkhand', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram',
#        'Nagaland', 'Odisha', 'Orissa', 'Pondicherry', 'Puducherry',
#        'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana',
#        'Karnataka', 'Kerala', 'Ladakh', 'Madhya Pradesh',
#        'Andaman & Nicobar Islands', 'Andaman and Nicobar Islands',
#        'Andhra Pradesh', 'Arunachal Pradesh', 'Dadra & Nagar Haveli',
#        'Dadra and Nagar Haveli', 'Lakshadweep', 'Tripura',
#        'Daman and Diu', 'Jammu & Kashmir', 'Daman & Diu', 'WEST BENGAL',
#        'ODISHA', 'Chhatisgarh', 'Westbengal', 'West  Bengal', 'Tamilnadu',
#        'andhra pradesh'], dtype=object)

# %%
demo_3=pd.read_csv("/content/drive/MyDrive/api_data_aadhar_biometric/api_data_aadhar_biometric_1500000_1861108.csv")
demo_3['new_date']=pd.to_datetime(demo_3['date'], format='%d-%m-%Y').dt.strftime('%Y%m%d')
demo_3
# Out:
#               date          state        district  pincode  bio_age_5_17  \
# 0       08-12-2025  Uttar Pradesh       Moradabad   244411             4
# 1       08-12-2025  Uttar Pradesh       Moradabad   244601            14
# 2       08-12-2025  Uttar Pradesh   Muzaffarnagar   251002            22
# 3       08-12-2025  Uttar Pradesh   Muzaffarnagar   251202             4
# 4       08-12-2025  Uttar Pradesh   Muzaffarnagar   251319             4
# ...            ...            ...             ...      ...           ...
# 361103  29-12-2025    West Bengal  Uttar Dinajpur   733201             4
# 361104  29-12-2025    West Bengal  Uttar Dinajpur   733213             0
# 361105  29-12-2025    West Bengal  West Midnapore   721304             0
# 361106  29-12-2025    West Bengal  West Midnapore   721451             2
# 361107  29-12-2025    West Bengal  West Midnapore   721457             0
#
#         bio_age_17_  new_date
# 0                 2  20251208
# 1                19  20251208
# 2                37  20251208
# 3                 4  20251208
# 4                 7  20251208
# ...             ...       ...
# 361103            9  20251229
# 361104            1  20251229
# 361105            3  20251229
# 361106            0  20251229
# 361107            1  20251229
#
# [361108 rows x 7 columns]

# %%
demo_3['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
print(demo_3['new_date'].max())
print(demo_3['new_date'].min())
# Out:
# 20251229
# 20251208

# %% [markdown]
# ### Importing Demography-4 data

# %%
demo_4=pd.read_csv("/content/drive/MyDrive/api_data_aadhar_biometric/api_data_aadhar_biometric_1500000_1861108.csv")
demo_4.head()
# Out:
#          date          state       district  pincode  bio_age_5_17  \
# 0  08-12-2025  Uttar Pradesh      Moradabad   244411             4
# 1  08-12-2025  Uttar Pradesh      Moradabad   244601            14
# 2  08-12-2025  Uttar Pradesh  Muzaffarnagar   251002            22
# 3  08-12-2025  Uttar Pradesh  Muzaffarnagar   251202             4
# 4  08-12-2025  Uttar Pradesh  Muzaffarnagar   251319             4
#
#    bio_age_17_
# 0            2
# 1           19
# 2           37
# 3            4
# 4            7

# %%
demo_4.shape
# Out:
# (361108, 6)

# %%
demo_4=pd.read_csv("/content/drive/MyDrive/api_data_aadhar_biometric/api_data_aadhar_biometric_1500000_1861108.csv")
demo_4['new_date']=pd.to_datetime(demo_4['date'], format='%d-%m-%Y').dt.strftime('%Y%m%d')
demo_4
# Out:
#               date          state        district  pincode  bio_age_5_17  \
# 0       08-12-2025  Uttar Pradesh       Moradabad   244411             4
# 1       08-12-2025  Uttar Pradesh       Moradabad   244601            14
# 2       08-12-2025  Uttar Pradesh   Muzaffarnagar   251002            22
# 3       08-12-2025  Uttar Pradesh   Muzaffarnagar   251202             4
# 4       08-12-2025  Uttar Pradesh   Muzaffarnagar   251319             4
# ...            ...            ...             ...      ...           ...
# 361103  29-12-2025    West Bengal  Uttar Dinajpur   733201             4
# 361104  29-12-2025    West Bengal  Uttar Dinajpur   733213             0
# 361105  29-12-2025    West Bengal  West Midnapore   721304             0
# 361106  29-12-2025    West Bengal  West Midnapore   721451             2
# 361107  29-12-2025    West Bengal  West Midnapore   721457             0
#
#         bio_age_17_  new_date
# 0                 2  20251208
# 1                19  20251208
# 2                37  20251208
# 3                 4  20251208
# 4                 7  20251208
# ...             ...       ...
# 361103            9  20251229
# 361104            1  20251229
# 361105            3  20251229
# 361106            0  20251229
# 361107            1  20251229
#
# [361108 rows x 7 columns]

# %%
print(demo_4['new_date'].max())
print(demo_4['new_date'].min())
# Out:
# 20251229
# 20251208

# %% [markdown]
# ### Merging three dataset

# %%
#Merging all the files

df = pd.concat([demo_1, demo_2, demo_3, demo_4], axis=0, ignore_index=True)
df.shape
# Out:
# (1722216, 7)

# %%
df.head()
# Out:
#          date              state      district  pincode  bio_age_5_17  \
# 0  01-03-2025            Haryana  Mahendragarh   123029           280
# 1  01-03-2025              Bihar     Madhepura   852121           144
# 2  01-03-2025  Jammu and Kashmir         Punch   185101           643
# 3  01-03-2025              Bihar       Bhojpur   802158           256
# 4  01-03-2025         Tamil Nadu       Madurai   625514           271
#
#    bio_age_17_  new_date
# 0          577  20250301
# 1          369  20250301
# 2         1091  20250301
# 3          980  20250301
# 4          815  20250301

# %%
# checking shape of data
df.shape
# Out:
# (1722216, 7)

# %%
# checking null values in date
df['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
# count unique value of state
df['state'].nunique()
# Out:
# 57

# %%
df['state'].unique()
# Out:
# array(['Haryana', 'Bihar', 'Jammu and Kashmir', 'Tamil Nadu',
#        'Maharashtra', 'Gujarat', 'Odisha', 'West Bengal', 'Kerala',
#        'Rajasthan', 'Punjab', 'Himachal Pradesh', 'Uttar Pradesh',
#        'Assam', 'Uttarakhand', 'Madhya Pradesh', 'Karnataka',
#        'Andhra Pradesh', 'Telangana', 'Goa', 'Nagaland', 'Jharkhand',
#        'Delhi', 'Chhattisgarh', 'Meghalaya', 'Chandigarh', 'Orissa',
#        'Puducherry', 'Pondicherry', 'Manipur', 'Sikkim', 'Tripura',
#        'Mizoram', 'Arunachal Pradesh', 'Ladakh',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Daman and Diu',
#        'Andaman and Nicobar Islands', 'Andaman & Nicobar Islands',
#        'Dadra and Nagar Haveli', 'Lakshadweep', 'Daman & Diu',
#        'Dadra & Nagar Haveli', 'Jammu & Kashmir', 'WESTBENGAL',
#        'andhra pradesh', 'Westbengal', 'West  Bengal', 'WEST BENGAL',
#        'West Bangal', 'ODISHA', 'odisha', 'West bengal', 'west Bengal',
#        'Uttaranchal', 'Chhatisgarh', 'Tamilnadu'], dtype=object)

# %% [markdown]
# # checking data consistency

# %%
df[df['state']=='Uttaranchal']
# Out:
#               date        state district  pincode  bio_age_5_17  bio_age_17_  \
# 374898  13-09-2025  Uttaranchal   Almora   263601             0            1
# 931510  05-12-2025  Uttaranchal  Garhwal   249302             0            1
#
#         new_date
# 374898  20250913
# 931510  20251205

# %% [markdown]
# ## Mappind state with correct name

# %%
df['state'] = df['state'].replace('Uttaranchal', 'Uttarakhand')

# %%
df['state'] = df['state'].replace('Tamilnadu', 'Tamil Nadu')

# %% [markdown]
# ## Mapping the state name

# %%
import pandas as pd
import re

def clean_state_name(x):
    if pd.isna(x):
        return x
    x = str(x).lower()
    x = re.sub(r'[^a-z\s]', ' ', x)   # remove symbols like &, .
    x = re.sub(r'\s+', ' ', x).strip()  # remove extra spaces
    return x

# %%
state_mapping = {
    # West Bengal
    'west bengal': 'West Bengal',
    'west bangal': 'West Bengal',
    'westbengal': 'West Bengal',
    'west  bengal': 'West Bengal',
    'westbengal ': 'West Bengal',
    'west bengli':  'West Bengal',


    # Andhra Pradesh
    'andhra pradesh': 'Andhra Pradesh',

    # Odisha
    'odisha': 'Odisha',
    'orissa': 'Odisha',

    # Jammu & Kashmir
    'jammu and kashmir': 'Jammu and Kashmir',
    'jammu kashmir': 'Jammu and Kashmir',

    # Collapse all Dadra / Daman variants into ONE state
    'dadra nagar haveli': 'Dadra and Nagar Haveli and Daman and Diu',
    'dadra and nagar haveli': 'Dadra and Nagar Haveli and Daman and Diu',
    'daman and diu': 'Dadra and Nagar Haveli and Daman and Diu',
    'dadra and nagar haveli and daman and diu': 'Dadra and Nagar Haveli and Daman and Diu',
    'the dadra and nagar haveli and daman and diu': 'Dadra and Nagar Haveli and Daman and Diu',
    'daman diu': 'Dadra and Nagar Haveli and Daman and Diu',


    # Puducherry
    'puducherry': 'Puducherry',


    # Andaman & Nicobar Islands
    'andaman and nicobar islands': 'Andaman and Nicobar Islands',
    'andaman nicobar islands': 'Andaman and Nicobar Islands',

    # Puducherry
    'pondicherry': 'Puducherry',

    # Case-normalized direct matches
    'delhi': 'Delhi',
    'ladakh': 'Ladakh',
    'goa': 'Goa',
    'sikkim': 'Sikkim',
    'assam': 'Assam',
    'bihar': 'Bihar',
    'punjab': 'Punjab',
    'kerala': 'Kerala',
    'haryana': 'Haryana',
    'gujarat': 'Gujarat',
    'tamil nadu': 'Tamil Nadu',
    'telangana': 'Telangana',
    'karnataka': 'Karnataka',
    'maharashtra': 'Maharashtra',
    'Nagpur': 'Maharashtra',
    'rajasthan': 'Rajasthan',
    'uttar pradesh': 'Uttar Pradesh',
    'madhya pradesh': 'Madhya Pradesh',
    'himachal pradesh': 'Himachal Pradesh',
    'arunachal pradesh': 'Arunachal Pradesh',
    'chhattisgarh': 'Chhattisgarh',
    'chhatisgarh' : 'Chhattisgarh',
    'jharkhand': 'Jharkhand',
    'manipur': 'Manipur',
    'meghalaya': 'Meghalaya',
    'mizoram': 'Mizoram',
    'nagaland': 'Nagaland',
    'tripura': 'Tripura',
    'uttarakhand': 'Uttarakhand',
    'lakshadweep': 'Lakshadweep',
    'chandigarh': 'Chandigarh'
}

# %%
df['state_clean'] = (
    df['state']
    .apply(clean_state_name)
    .map(state_mapping)
)

# %%
# Drop invalid entries like numeric junk
df = df[~df['state'].astype(str).str.isnumeric()]

# Optional: check unmapped states
unmapped = df[df['state_clean'].isna()]['state'].unique()
print("Unmapped values:", unmapped)
# Out:
# Unmapped values: []

# %%
df.tail(20)
# Out:
#                date        state                    district  pincode  \
# 1722196  29-12-2025  West Bengal           South 24 Parganas   743375
# 1722197  29-12-2025  West Bengal           South 24 Parganas   743378
# 1722198  29-12-2025  West Bengal           South 24 Parganas   743384
# 1722199  29-12-2025  West Bengal           South 24 Parganas   743392
# 1722200  29-12-2025  West Bengal           South 24 Parganas   743502
# 1722201  29-12-2025  West Bengal              South Dinajpur   733126
# 1722202  29-12-2025  West Bengal              South Dinajpur   733140
# 1722203  29-12-2025  West Bengal              South Dinajpur   733145
# 1722204  29-12-2025  West Bengal              South Dinajpur   733153
# 1722205  29-12-2025  West Bengal              South Dinajpur   733155
# 1722206  29-12-2025  West Bengal  South Twenty Four Parganas   700084
# 1722207  29-12-2025  West Bengal  South Twenty Four Parganas   700145
# 1722208  29-12-2025  West Bengal  South Twenty Four Parganas   743348
# 1722209  29-12-2025  West Bengal  South Twenty Four Parganas   743370
# 1722210  29-12-2025  West Bengal  South Twenty Four Parganas   743373
# 1722211  29-12-2025  West Bengal              Uttar Dinajpur   733201
# 1722212  29-12-2025  West Bengal              Uttar Dinajpur   733213
# 1722213  29-12-2025  West Bengal              West Midnapore   721304
# 1722214  29-12-2025  West Bengal              West Midnapore   721451
# 1722215  29-12-2025  West Bengal              West Midnapore   721457
#
#          bio_age_5_17  bio_age_17_  new_date  state_clean
# 1722196             2            3  20251229  West Bengal
# 1722197             2            3  20251229  West Bengal
# 1722198             2            0  20251229  West Bengal
# 1722199             0            1  20251229  West Bengal
# 1722200             9            5  20251229  West Bengal
# 1722201             0            4  20251229  West Bengal
# 1722202             0            1  20251229  West Bengal
# 1722203             0            1  20251229  West Bengal
# 1722204             1            0  20251229  West Bengal
# 1722205             1            1  20251229  West Bengal
# 1722206             0            1  20251229  West Bengal
# 1722207             1            3  20251229  West Bengal
# 1722208             0            1  20251229  West Bengal
# 1722209             1            0  20251229  West Bengal
# 1722210             1            8  20251229  West Bengal
# 1722211             4            9  20251229  West Bengal
# 1722212             0            1  20251229  West Bengal
# 1722213             0            3  20251229  West Bengal
# 1722214             2            0  20251229  West Bengal
# 1722215             0            1  20251229  West Bengal

# %%
df['state_clean'].unique()
# Out:
# array(['Haryana', 'Bihar', 'Jammu and Kashmir', 'Tamil Nadu',
#        'Maharashtra', 'Gujarat', 'Odisha', 'West Bengal', 'Kerala',
#        'Rajasthan', 'Punjab', 'Himachal Pradesh', 'Uttar Pradesh',
#        'Assam', 'Uttarakhand', 'Madhya Pradesh', 'Karnataka',
#        'Andhra Pradesh', 'Telangana', 'Goa', 'Nagaland', 'Jharkhand',
#        'Delhi', 'Chhattisgarh', 'Meghalaya', 'Chandigarh', 'Puducherry',
#        'Manipur', 'Sikkim', 'Tripura', 'Mizoram', 'Arunachal Pradesh',
#        'Ladakh', 'Dadra and Nagar Haveli and Daman and Diu',
#        'Andaman and Nicobar Islands', 'Lakshadweep'], dtype=object)

# %%
df['state_clean'].nunique()
# Out:
# 36

# %%
#checking datatypes
df.dtypes
# Out:
# date            object
# state           object
# district        object
# pincode          int64
# bio_age_5_17     int64
# bio_age_17_      int64
# new_date        object
# state_clean     object
# dtype: object

# %%
df
# Out:
#                date              state        district  pincode  bio_age_5_17  \
# 0        01-03-2025            Haryana    Mahendragarh   123029           280
# 1        01-03-2025              Bihar       Madhepura   852121           144
# 2        01-03-2025  Jammu and Kashmir           Punch   185101           643
# 3        01-03-2025              Bihar         Bhojpur   802158           256
# 4        01-03-2025         Tamil Nadu         Madurai   625514           271
# ...             ...                ...             ...      ...           ...
# 1722211  29-12-2025        West Bengal  Uttar Dinajpur   733201             4
# 1722212  29-12-2025        West Bengal  Uttar Dinajpur   733213             0
# 1722213  29-12-2025        West Bengal  West Midnapore   721304             0
# 1722214  29-12-2025        West Bengal  West Midnapore   721451             2
# 1722215  29-12-2025        West Bengal  West Midnapore   721457             0
#
#          bio_age_17_  new_date        state_clean
# 0                577  20250301            Haryana
# 1                369  20250301              Bihar
# 2               1091  20250301  Jammu and Kashmir
# 3                980  20250301              Bihar
# 4                815  20250301         Tamil Nadu
# ...              ...       ...                ...
# 1722211            9  20251229        West Bengal
# 1722212            1  20251229        West Bengal
# 1722213            3  20251229        West Bengal
# 1722214            0  20251229        West Bengal
# 1722215            1  20251229        West Bengal
#
# [1722216 rows x 8 columns]

# %% [markdown]
# ## Filtering data on state (Bihar)

# %%
df_bihar=df[df['state_clean']=='Bihar']
df_bihar
# Out:
#                date  state        district  pincode  bio_age_5_17  \
# 1        01-03-2025  Bihar       Madhepura   852121           144
# 3        01-03-2025  Bihar         Bhojpur   802158           256
# 15       01-03-2025  Bihar        Vaishali   844504           426
# 56       01-03-2025  Bihar         Bhojpur   802164           165
# 72       01-03-2025  Bihar       Darbhanga   846003           438
# ...             ...    ...             ...      ...           ...
# 1718347  29-12-2025  Bihar        Vaishali   844131             1
# 1718348  29-12-2025  Bihar        Vaishali   844134             2
# 1718349  29-12-2025  Bihar        Vaishali   844502            12
# 1718350  29-12-2025  Bihar  West Champaran   845101            42
# 1718351  29-12-2025  Bihar  West Champaran   845307            26
#
#          bio_age_17_  new_date state_clean
# 1                369  20250301       Bihar
# 3                980  20250301       Bihar
# 15               958  20250301       Bihar
# 56               311  20250301       Bihar
# 72               859  20250301       Bihar
# ...              ...       ...         ...
# 1718347            3  20251229       Bihar
# 1718348            3  20251229       Bihar
# 1718349            8  20251229       Bihar
# 1718350           32  20251229       Bihar
# 1718351           23  20251229       Bihar
#
# [76351 rows x 8 columns]

# %%
df_bihar['district'].unique()
# Out:
# array(['Madhepura', 'Bhojpur', 'Vaishali', 'Darbhanga', 'Saharsa',
#        'Katihar', 'Patna', 'Supaul', 'Begusarai', 'Banka', 'Bhagalpur',
#        'Saran', 'Jehanabad', 'Muzaffarpur', 'West Champaran', 'Rohtas',
#        'Jamui', 'Gopalganj', 'Nalanda', 'Samastipur', 'Araria', 'Siwan',
#        'Aurangabad', 'Khagaria', 'Gaya', 'Purnia', 'Madhubani',
#        'Sheikhpura', 'Buxar', 'Purnea', 'Munger', 'East Champaran',
#        'Sitamarhi', 'Lakhisarai', 'Nawada', 'Kishanganj', 'Sheohar',
#        'Arwal', 'Kaimur (Bhabua)', 'Pashchim Champaran', 'Aurangabad(bh)',
#        'Monghyr', 'Samstipur', 'Sheikpura', 'Purba Champaran', 'Bhabua',
#        'Aurangabad(BH)'], dtype=object)

# %%
# df_bihar['district'] = df_bihar['district'].replace('Near University Thana', 'Darbhanga')

# %%
import re
import pandas as pd

def clean_name(x):
    if pd.isna(x):
        return x
    x = str(x).lower()
    x = re.sub(r'[^a-z\s]', ' ', x)   # remove (), ., etc
    x = re.sub(r'\s+', ' ', x).strip()
    return x

# %%
district_mapping_bihar = {

    # Champaran
    'purbi champaran': 'East Champaran',
    'purba champaran': 'East Champaran',
    'east champaran': 'East Champaran',

    'pashchim champaran': 'West Champaran',
    'west champaran': 'West Champaran',

    # Aurangabad
    'aurangabad bh': 'Aurangabad',
    'aurangabad bh ': 'Aurangabad',
    'aurangabad': 'Aurangabad',

    # Purnia
    'purnia': 'Purnia',
    'purnea': 'Purnia',

    # Kaimur
    'kaimur bhabua': 'Kaimur',
    'bhabua': 'Kaimur',

    # Munger
    'munger': 'Munger',
    'monghyr': 'Munger',

    # Samastipur
    'samastipur': 'Samastipur',
    'samstipur': 'Samastipur',

    # Sheikhpura
    'sheikhpura': 'Sheikhpura',
    'sheikpura': 'Sheikhpura',
    'monghyr' : 'Munger',

    # Normalized direct matches
    'sitamarhi': 'Sitamarhi',
    'madhubani': 'Madhubani',
    'bhagalpur': 'Bhagalpur',
    'patna': 'Patna',
    'muzaffarpur': 'Muzaffarpur',
    'gaya': 'Gaya',
    'saran': 'Saran',
    'vaishali': 'Vaishali',
    'jehanabad': 'Jehanabad',
    'jamui': 'Jamui',
    'gopalganj': 'Gopalganj',
    'saharsa': 'Saharsa',
    'arwal': 'Arwal',
    'katihar': 'Katihar',
    'siwan': 'Siwan',
    'lakhisarai': 'Lakhisarai',
    'banka': 'Banka',
    'nalanda': 'Nalanda',
    'araria': 'Araria',
    'darbhanga': 'Darbhanga',
    'nawada': 'Nawada',
    'begusarai': 'Begusarai',
    'bhojpur': 'Bhojpur',
    'buxar': 'Buxar',
    'khagaria': 'Khagaria',
    'kishanganj': 'Kishanganj',
    'madhepura': 'Madhepura',
    'rohtas': 'Rohtas',
    'sheohar': 'Sheohar',
    'supaul': 'Supaul'
}

# %%
df_bihar['district_clean'] = (
    df_bihar['district']
    .apply(clean_name)
    .map(district_mapping_bihar)
    .fillna(df_bihar['district'])
)
# Out:
# /tmp/ipython-input-828442334.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bihar['district_clean'] = (

# %%
# Remaining unmapped
df_bihar[df_bihar['district_clean'].isna()]['district'].unique()

# Count check
df_bihar['district_clean'].nunique()
# Out:
# 38

# %%
df_bihar
# Out:
#                date  state        district  pincode  bio_age_5_17  \
# 1        01-03-2025  Bihar       Madhepura   852121           144
# 3        01-03-2025  Bihar         Bhojpur   802158           256
# 15       01-03-2025  Bihar        Vaishali   844504           426
# 56       01-03-2025  Bihar         Bhojpur   802164           165
# 72       01-03-2025  Bihar       Darbhanga   846003           438
# ...             ...    ...             ...      ...           ...
# 1718347  29-12-2025  Bihar        Vaishali   844131             1
# 1718348  29-12-2025  Bihar        Vaishali   844134             2
# 1718349  29-12-2025  Bihar        Vaishali   844502            12
# 1718350  29-12-2025  Bihar  West Champaran   845101            42
# 1718351  29-12-2025  Bihar  West Champaran   845307            26
#
#          bio_age_17_  new_date state_clean  district_clean
# 1                369  20250301       Bihar       Madhepura
# 3                980  20250301       Bihar         Bhojpur
# 15               958  20250301       Bihar        Vaishali
# 56               311  20250301       Bihar         Bhojpur
# 72               859  20250301       Bihar       Darbhanga
# ...              ...       ...         ...             ...
# 1718347            3  20251229       Bihar        Vaishali
# 1718348            3  20251229       Bihar        Vaishali
# 1718349            8  20251229       Bihar        Vaishali
# 1718350           32  20251229       Bihar  West Champaran
# 1718351           23  20251229       Bihar  West Champaran
#
# [76351 rows x 9 columns]

# %%
df_bihar['district_clean'].unique()
# Out:
# array(['Madhepura', 'Bhojpur', 'Vaishali', 'Darbhanga', 'Saharsa',
#        'Katihar', 'Patna', 'Supaul', 'Begusarai', 'Banka', 'Bhagalpur',
#        'Saran', 'Jehanabad', 'Muzaffarpur', 'West Champaran', 'Rohtas',
#        'Jamui', 'Gopalganj', 'Nalanda', 'Samastipur', 'Araria', 'Siwan',
#        'Aurangabad', 'Khagaria', 'Gaya', 'Purnia', 'Madhubani',
#        'Sheikhpura', 'Buxar', 'Munger', 'East Champaran', 'Sitamarhi',
#        'Lakhisarai', 'Nawada', 'Kishanganj', 'Sheohar', 'Arwal', 'Kaimur'],
#       dtype=object)

# %%
df_bihar['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
df_bihar['district_clean'].isnull().sum()
# Out:
# np.int64(0)

# %%
df_bihar['pincode'].nunique()
# Out:
# 915

# %%
# df_bihar[['district_clean','pincode']].value_counts().reset_index(name='count')

# %%
pincode_check=df_bihar.groupby('district_clean')['pincode'].nunique().reset_index(name='unique_pincode_count')

# %%
df_bihar[df_bihar['district_clean']=='Kaimur']['pincode'].unique()
# Out:
# array([821106, 821112, 821105, 821102, 821103, 821104, 802132, 821108,
#        821110, 821101, 821109, 821304, 802212, 802215, 821107, 802213,
#        821312, 802218, 821310, 821113])

# %%
pin_district_count = (
    df_bihar.groupby('pincode')['district_clean']
      .nunique()
      .reset_index(name='district_count')
)

# %%
pin_district_count
# Out:
#      pincode  district_count
# 0     431010               1
# 1     800001               1
# 2     800002               1
# 3     800003               1
# 4     800004               1
# ..       ...             ...
# 910   855114               1
# 911   855115               2
# 912   855116               1
# 913   855117               2
# 914   855456               1
#
# [915 rows x 2 columns]

# %%
problem_pins = pin_district_count[
    pin_district_count['district_count'] > 1
]

# %%
problem_pins
# Out:
#      pincode  district_count
# 44    801304               2
# 45    801305               2
# 57    802112               2
# 72    802129               2
# 77    802134               2
# ..       ...             ...
# 903   855101               2
# 905   855105               2
# 907   855107               3
# 911   855115               2
# 913   855117               2
#
# [199 rows x 2 columns]

# %%
df_flagged = df_bihar.merge(
    problem_pins[['pincode']],
    on='pincode',
    how='inner'
)

# %%
df_flagged
# Out:
#              date  state   district  pincode  bio_age_5_17  bio_age_17_  \
# 0      01-03-2025  Bihar  Madhepura   852121           144          369
# 1      01-03-2025  Bihar    Saharsa   852210            58          118
# 2      01-03-2025  Bihar    Katihar   855105           684          838
# 3      01-03-2025  Bihar     Supaul   852123            43           87
# 4      01-03-2025  Bihar  Darbhanga   847306           330          381
# ...           ...    ...        ...      ...           ...          ...
# 24302  29-12-2025  Bihar  Sitamarhi   843328            24           28
# 24303  29-12-2025  Bihar  Sitamarhi   843334             0            1
# 24304  29-12-2025  Bihar      Siwan   841427             4            0
# 24305  29-12-2025  Bihar      Siwan   841436             5            8
# 24306  29-12-2025  Bihar   Vaishali   843102             6            4
#
#        new_date state_clean district_clean
# 0      20250301       Bihar      Madhepura
# 1      20250301       Bihar        Saharsa
# 2      20250301       Bihar        Katihar
# 3      20250301       Bihar         Supaul
# 4      20250301       Bihar      Darbhanga
# ...         ...         ...            ...
# 24302  20251229       Bihar      Sitamarhi
# 24303  20251229       Bihar      Sitamarhi
# 24304  20251229       Bihar          Siwan
# 24305  20251229       Bihar          Siwan
# 24306  20251229       Bihar       Vaishali
#
# [24307 rows x 9 columns]

# %%
flagged_pincode_dominant=df_flagged.groupby(['district_clean', 'pincode'])[['bio_age_5_17','bio_age_17_']].sum().reset_index()
flagged_pincode_dominant.to_excel('flagged_pincode_dominant_bio.xlsx')

# %%
flagged_pincode_dominant['total_enroll']=flagged_pincode_dominant['bio_age_5_17']+flagged_pincode_dominant['bio_age_17_']
flagged_pincode_dominant.sort_values('pincode')
# Out:
#     district_clean  pincode  bio_age_5_17  bio_age_17_  total_enroll
# 253        Nalanda   801304          1052         1185          2237
# 277          Patna   801304           618          610          1228
# 278          Patna   801305           715          717          1432
# 254        Nalanda   801305          1451         1386          2837
# 72         Bhojpur   802112          1059          919          1978
# ..             ...      ...           ...          ...           ...
# 189     Kishanganj   855107         14364        18180         32544
# 315         Purnia   855115          1536         2072          3608
# 190     Kishanganj   855115          7731         7824         15555
# 191     Kishanganj   855117          9560         9191         18751
# 179        Katihar   855117             1            5             6
#
# [413 rows x 5 columns]

# %%
idx = flagged_pincode_dominant.groupby('pincode')['total_enroll'].idxmax()
df_filtered = flagged_pincode_dominant.loc[idx]
df_filtered
# Out:
#     district_clean  pincode  bio_age_5_17  bio_age_17_  total_enroll
# 253        Nalanda   801304          1052         1185          2237
# 254        Nalanda   801305          1451         1386          2837
# 80           Buxar   802112           999         1135          2134
# 81           Buxar   802129          1245         1923          3168
# 82           Buxar   802134          1140         1773          2913
# ..             ...      ...           ...          ...           ...
# 188     Kishanganj   855101         17457        20366         37823
# 178        Katihar   855105          3912         5053          8965
# 189     Kishanganj   855107         14364        18180         32544
# 190     Kishanganj   855115          7731         7824         15555
# 191     Kishanganj   855117          9560         9191         18751
#
# [199 rows x 5 columns]

# %%
df_bihar['pin_multi_district_flag'] = (
    df_bihar.groupby('pincode')['district']
      .transform('nunique') > 1
)
# Out:
# /tmp/ipython-input-3362433199.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bihar['pin_multi_district_flag'] = (

# %%
pin_district_map = (
    df_bihar[df_bihar['pin_multi_district_flag']]
    .groupby('pincode')['district_clean']
    .unique()
    .reset_index()
)

# %%
pin_district_map
# Out:
#      pincode                district_clean
# 0     801304              [Patna, Nalanda]
# 1     801305              [Nalanda, Patna]
# 2     802112              [Bhojpur, Buxar]
# 3     802129              [Buxar, Bhojpur]
# 4     802132                      [Kaimur]
# ..       ...                           ...
# 294   855105             [Katihar, Purnia]
# 295   855107  [Kishanganj, Purnia, Araria]
# 296   855115          [Kishanganj, Purnia]
# 297   855117         [Kishanganj, Katihar]
# 298   855456              [East Champaran]
#
# [299 rows x 2 columns]

# %%
file_path='pin_district_bio_map.xlsx'
#pin_district_map.to_excel(file_path, index=False)

# %%
df_bihar['pin_multi_district_flag'].value_counts()
# Out:
# pin_multi_district_flag
# False    43525
# True     32826
# Name: count, dtype: int64

# %%
df_bihar['total_enroll']=df_bihar['bio_age_5_17']+df_bihar['bio_age_17_']
df_bihar
# Out:
# /tmp/ipython-input-4162557340.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bihar['total_enroll']=df_bihar['bio_age_5_17']+df_bihar['bio_age_17_']
#                date  state        district  pincode  bio_age_5_17  \
# 1        01-03-2025  Bihar       Madhepura   852121           144
# 3        01-03-2025  Bihar         Bhojpur   802158           256
# 15       01-03-2025  Bihar        Vaishali   844504           426
# 56       01-03-2025  Bihar         Bhojpur   802164           165
# 72       01-03-2025  Bihar       Darbhanga   846003           438
# ...             ...    ...             ...      ...           ...
# 1718347  29-12-2025  Bihar        Vaishali   844131             1
# 1718348  29-12-2025  Bihar        Vaishali   844134             2
# 1718349  29-12-2025  Bihar        Vaishali   844502            12
# 1718350  29-12-2025  Bihar  West Champaran   845101            42
# 1718351  29-12-2025  Bihar  West Champaran   845307            26
#
#          bio_age_17_  new_date state_clean  district_clean  \
# 1                369  20250301       Bihar       Madhepura
# 3                980  20250301       Bihar         Bhojpur
# 15               958  20250301       Bihar        Vaishali
# 56               311  20250301       Bihar         Bhojpur
# 72               859  20250301       Bihar       Darbhanga
# ...              ...       ...         ...             ...
# 1718347            3  20251229       Bihar        Vaishali
# 1718348            3  20251229       Bihar        Vaishali
# 1718349            8  20251229       Bihar        Vaishali
# 1718350           32  20251229       Bihar  West Champaran
# 1718351           23  20251229       Bihar  West Champaran
#
#          pin_multi_district_flag  total_enroll
# 1                           True           513
# 3                          False          1236
# 15                         False          1384
# 56                         False           476
# 72                         False          1297
# ...                          ...           ...
# 1718347                    False             4
# 1718348                    False             5
# 1718349                    False            20
# 1718350                     True            74
# 1718351                    False            49
#
# [76351 rows x 11 columns]

# %%
df_bihar['month']=df_bihar['new_date'].astype(str).str[4:6]
df_bihar
# Out:
# /tmp/ipython-input-3723542462.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bihar['month']=df_bihar['new_date'].astype(str).str[4:6]
#                date  state        district  pincode  bio_age_5_17  \
# 1        01-03-2025  Bihar       Madhepura   852121           144
# 3        01-03-2025  Bihar         Bhojpur   802158           256
# 15       01-03-2025  Bihar        Vaishali   844504           426
# 56       01-03-2025  Bihar         Bhojpur   802164           165
# 72       01-03-2025  Bihar       Darbhanga   846003           438
# ...             ...    ...             ...      ...           ...
# 1718347  29-12-2025  Bihar        Vaishali   844131             1
# 1718348  29-12-2025  Bihar        Vaishali   844134             2
# 1718349  29-12-2025  Bihar        Vaishali   844502            12
# 1718350  29-12-2025  Bihar  West Champaran   845101            42
# 1718351  29-12-2025  Bihar  West Champaran   845307            26
#
#          bio_age_17_  new_date state_clean  district_clean  \
# 1                369  20250301       Bihar       Madhepura
# 3                980  20250301       Bihar         Bhojpur
# 15               958  20250301       Bihar        Vaishali
# 56               311  20250301       Bihar         Bhojpur
# 72               859  20250301       Bihar       Darbhanga
# ...              ...       ...         ...             ...
# 1718347            3  20251229       Bihar        Vaishali
# 1718348            3  20251229       Bihar        Vaishali
# 1718349            8  20251229       Bihar        Vaishali
# 1718350           32  20251229       Bihar  West Champaran
# 1718351           23  20251229       Bihar  West Champaran
#
#          pin_multi_district_flag  total_enroll month
# 1                           True           513    03
# 3                          False          1236    03
# 15                         False          1384    03
# 56                         False           476    03
# 72                         False          1297    03
# ...                          ...           ...   ...
# 1718347                    False             4    12
# 1718348                    False             5    12
# 1718349                    False            20    12
# 1718350                     True            74    12
# 1718351                    False            49    12
#
# [76351 rows x 12 columns]

# %%
df_bihar_cleaned=df_bihar.drop(columns=['date','district','state'], axis=1)
df_bihar_cleaned
# Out:
#          pincode  bio_age_5_17  bio_age_17_  new_date state_clean  \
# 1         852121           144          369  20250301       Bihar
# 3         802158           256          980  20250301       Bihar
# 15        844504           426          958  20250301       Bihar
# 56        802164           165          311  20250301       Bihar
# 72        846003           438          859  20250301       Bihar
# ...          ...           ...          ...       ...         ...
# 1718347   844131             1            3  20251229       Bihar
# 1718348   844134             2            3  20251229       Bihar
# 1718349   844502            12            8  20251229       Bihar
# 1718350   845101            42           32  20251229       Bihar
# 1718351   845307            26           23  20251229       Bihar
#
#          district_clean  pin_multi_district_flag  total_enroll month
# 1             Madhepura                     True           513    03
# 3               Bhojpur                    False          1236    03
# 15             Vaishali                    False          1384    03
# 56              Bhojpur                    False           476    03
# 72            Darbhanga                    False          1297    03
# ...                 ...                      ...           ...   ...
# 1718347        Vaishali                    False             4    12
# 1718348        Vaishali                    False             5    12
# 1718349        Vaishali                    False            20    12
# 1718350  West Champaran                     True            74    12
# 1718351  West Champaran                    False            49    12
#
# [76351 rows x 9 columns]

# %%
df_bihar_dist_level=df_bihar_cleaned.groupby('district_clean')[['bio_age_5_17','bio_age_17_','total_enroll']].sum()
df_bihar_dist_level.shape
# Out:
# (38, 3)

# %%
df_bihar_dist_level
# Out:
#                 bio_age_5_17  bio_age_17_  total_enroll
# district_clean
# Araria                 73107        80744        153851
# Arwal                  11749        18081         29830
# Aurangabad             45327        48834         94161
# Banka                  49399        46929         96328
# Begusarai              73379        75634        149013
# Bhagalpur              72181        74735        146916
# Bhojpur                38967        56860         95827
# Buxar                  24647        32153         56800
# Darbhanga              94334       115645        209979
# East Champaran         96607       116947        213554
# Gaya                   86071        99530        185601
# Gopalganj              47401        56112        103513
# Jamui                  51603        34463         86066
# Jehanabad              15226        21407         36633
# Kaimur                 35811        38591         74402
# Katihar                99616       115005        214621
# Khagaria               41731        40834         82565
# Kishanganj             65083        77774        142857
# Lakhisarai             22445        26444         48889
# Madhepura              53102        65641        118743
# Madhubani             112760       126766        239526
# Munger                 21781        29290         51071
# Muzaffarpur            93745       114714        208459
# Nalanda                52882        65222        118104
# Nawada                 38067        48362         86429
# Patna                  93044       114017        207061
# Purnia                108005       124261        232266
# Rohtas                 49517        60040        109557
# Saharsa                42178        75359        117537
# Samastipur             93913       108283        202196
# Saran                  63251        85209        148460
# Sheikhpura             16438        22662         39100
# Sheohar                13084        19580         32664
# Sitamarhi              85338        97100        182438
# Siwan                  52955        71642        124597
# Supaul                 47284        63300        110584
# Vaishali               72955        96338        169293
# West Champaran         77180        92114        169294

# %%
df_bihar_dist_level=df_bihar_dist_level.sort_values('total_enroll', ascending=False).reset_index()
#df_bihar_dist_level.to_excel("df_bihar_dist_bio_level.xlsx")

# %%
df_bihar_dist_level1=df_bihar_dist_level.head(10)
df_bihar_dist_level1
# Out:
#    district_clean  bio_age_5_17  bio_age_17_  total_enroll
# 0       Madhubani        112760       126766        239526
# 1          Purnia        108005       124261        232266
# 2         Katihar         99616       115005        214621
# 3  East Champaran         96607       116947        213554
# 4       Darbhanga         94334       115645        209979
# 5     Muzaffarpur         93745       114714        208459
# 6           Patna         93044       114017        207061
# 7      Samastipur         93913       108283        202196
# 8            Gaya         86071        99530        185601
# 9       Sitamarhi         85338        97100        182438

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 6))   # width, height in inches
sns.lineplot(data=df_bihar_dist_level1[['bio_age_5_17','bio_age_17_']])
plt.show()

# %%
df_bihar_pincode_level=df_bihar_cleaned.groupby('pincode')[['bio_age_5_17','bio_age_17_','total_enroll']].sum()
df_bihar_pincode_level.shape
# Out:
# (915, 3)

# %%
df_bihar_pincode_level.sort_values('total_enroll', ascending=False).reset_index()
#df_bihar_pincode_level.to_excel("df_bihar_pincode_bio_level.xlsx")
# Out:
#      pincode  bio_age_5_17  bio_age_17_  total_enroll
# 0     855101         17459        20373         37832
# 1     855107         16432        20919         37351
# 2     854315         17311        17576         34887
# 3     854317         16720        17438         34158
# 4     855113         13286        12863         26149
# ..       ...           ...          ...           ...
# 910   800028             2            0             2
# 911   824213             0            2             2
# 912   801111             2            0             2
# 913   431010             0            2             2
# 914   803218             0            1             1
#
# [915 rows x 4 columns]

# %%
df_bihar_pincode_level=df_bihar_pincode_level.sort_values('total_enroll', ascending=False).reset_index()

# %%
df_bihar_pincode_level1=df_bihar_pincode_level.head(10)
df_bihar_pincode_level1
# Out:
#    pincode  bio_age_5_17  bio_age_17_  total_enroll
# 0   855101         17459        20373         37832
# 1   855107         16432        20919         37351
# 2   854315         17311        17576         34887
# 3   854317         16720        17438         34158
# 4   855113         13286        12863         26149
# 5   854318         10552        13394         23946
# 6   854311         12898        10886         23784
# 7   854304          9859        13610         23469
# 8   843302         10853        12019         22872
# 9   845438         10085        12473         22558

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 6))   # width, height in inches
sns.lineplot(data=df_bihar_pincode_level1[['bio_age_5_17','bio_age_17_','total_enroll']])
plt.show()

# %%
bihar_month_enroll_trend=df_bihar_cleaned.groupby('month')[['bio_age_5_17','bio_age_17_','total_enroll']].sum()
bihar_month_enroll_trend
# Out:
#        bio_age_5_17  bio_age_17_  total_enroll
# month
# 03           324179       439330        763509
# 04           419994       375725        795719
# 05           283915       268284        552199
# 06           239119       255338        494457
# 07           253037       351024        604061
# 09           136695       213281        349976
# 11            97045       159529        256574
# 12           478179       594111       1072290

# %%
#bihar_month_enroll_trend.to_excel("df_bihar_month_bio_level.xlsx")

# %%
sns.lineplot(data=bihar_month_enroll_trend)
# Out:
# <Axes: xlabel='month'>
